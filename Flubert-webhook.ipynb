# %%
# Only need to do this once...
# !pip install flask
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Requirement already satisfied: flask in /usr/local/envs/py2env/lib/python2.7/site-packages (0.11.1)
# Requirement already satisfied: Jinja2>=2.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from flask) (2.8)
# Requirement already satisfied: click>=2.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from flask) (7.0)
# Requirement already satisfied: itsdangerous>=0.21 in /usr/local/envs/py2env/lib/python2.7/site-packages (from flask) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.7 in /usr/local/envs/py2env/lib/python2.7/site-packages (from flask) (0.15.4)
# Requirement already satisfied: MarkupSafe in /usr/local/envs/py2env/lib/python2.7/site-packages (from Jinja2>=2.4->flask) (1.1.1)

# %%
import json
import re
from flask import Flask, request, jsonify, make_response

from google.cloud import datastore

# %%
app = Flask(__name__)


@app.route('/webhook/', methods=['POST'])
def handle():
    req = request.get_json(silent=True, force=True)
    print 'Request:'
    print(json.dumps(req, indent=4))
    if req.get('queryResult').get('action') != 'lookup':
        return {}
    topic = req.get('queryResult').get('parameters').get('topic')
    topic = re.sub(r'[^\w\s]', '', topic)
    print topic
    rsp = getResponse(topic)
    rsp = json.dumps(rsp, indent=4)
    print rsp
    r = make_response(rsp)
    r.headers['Content-Type'] = 'application/json'
    return r

def getResponse(topic):
    
    client = datastore.Client()
    query = client.query(kind='Synonym')
    key = client.key('Synonym', topic)
    query.key_filter(key, '=')
    results = list(query.fetch())
    
    if len(results) == 0:
        return buildReply('Sorry can\'t find an answer to that yet since I\'m still learning...')
    
    print results[0]['synonym']
    
    query = client.query(kind='prenatal care')
    key = client.key('prenatal care', results[0]['synonym'])
    query.key_filter(key, '=')
    results = list(query.fetch())
    
    print results[0]['action_text']
    
    return buildReply(results[0]['action_text'])

def buildReply(info):
    return {
        'fulfillmentText': info,
    }

if __name__ == '__main__':
    app.run(host='0.0.0.0')
# Out:
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# [2020-07-09 22:48:59,518] ERROR in app: Exception on /webhook/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1988, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1642, in full_dispatch_request
#     response = self.make_response(rv)
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1746, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/werkzeug/wrappers/base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/werkzeug/wrappers/base_response.py", line 26, in _run_wsgi_app
#     return _run_wsgi_app(*args)
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/werkzeug/test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'dict' object is not callable
# 127.0.0.1 - - [09/Jul/2020 22:48:59] "POST /webhook/ HTTP/1.1" 500 -
# Request:
# {
#     "queryResult": {
#         "fulfillmentMessages": [
#             {
#                 "text": {
#                     "text": [
#                         ""
#                     ]
#                 }
#             }
#         ],
#         "allRequiredParamsPresent": true,
#         "parameters": {
#             "prenatal_care": [
#                 "prenatal appointment"
#             ]
#         },
#         "languageCode": "en",
#         "intentDetectionConfidence": 0.78616834,
#         "intent": {
#             "displayName": "prenatal_care",
#             "name": "projects/flubert1/agent/intents/ddf237c3-13ac-4b73-848f-ed2b4e4dda4f"
#         },
#         "queryText": "should i go to my prenatal appointment",
#         "outputContexts": [
#             {
#                 "name": "projects/flubert1/agent/sessions/cf31acbb-43e0-e466-c72c-aa5493ca67eb/contexts/__system_counters__",
#                 "parameters": {
#                     "prenatal_care": [
#                         "prenatal appointment"
#                     ],
#                     "prenatal_care.original": [
#                         "prenatal appointment"
#                     ],
#                     "no-match": 0.0,
#                     "no-input": 0.0
#                 }
#             }
#         ]
#     },
#     "originalDetectIntentRequest": {
#         "payload": {}
#     },
#     "session": "projects/flubert1/agent/sessions/cf31acbb-43e0-e466-c72c-aa5493ca67eb",
#     "responseId": "26f1df9a-fefe-4abf-91e3-45983bc3494d-425db6e2"
# }
# [2020-07-09 22:49:31,608] ERROR in app: Exception on /webhook/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1988, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1642, in full_dispatch_request
#     response = self.make_response(rv)
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/flask/app.py", line 1746, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/werkzeug/wrappers/base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "/usr/local/envs/py2env/lib/python2.7/site-packages/werkzeug/test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'dict' object is not callable
# 127.0.0.1 - - [09/Jul/2020 22:49:31] "POST /webhook/ HTTP/1.1" 500 -
# Request:
# {
#     "queryResult": {
#         "fulfillmentMessages": [
#             {
#                 "text": {
#                     "text": [
#                         ""
#                     ]
#                 }
#             }
#         ],
#         "allRequiredParamsPresent": true,
#         "parameters": {
#             "prenatal_care": [
#                 "prenatal class"
#             ]
#         },
#         "languageCode": "en",
#         "intentDetectionConfidence": 0.74781495,
#         "intent": {
#             "displayName": "prenatal_care",
#             "name": "projects/flubert1/agent/intents/ddf237c3-13ac-4b73-848f-ed2b4e4dda4f"
#         },
#         "queryText": "is it safe to take a prenatal class",
#         "outputContexts": [
#             {
#                 "name": "projects/flubert1/agent/sessions/cf31acbb-43e0-e466-c72c-aa5493ca67eb/contexts/__system_counters__",
#                 "parameters": {
#                     "prenatal_care": [
#                         "prenatal class"
#                     ],
#                     "prenatal_care.original": [
#                         "prenatal class"
#                     ],
#                     "no-match": 0.0,
#                     "no-input": 0.0
#                 }
#             }
#         ]
#     },
#     "originalDetectIntentRequest": {
#         "payload": {}
#     },
#     "session": "projects/flubert1/agent/sessions/cf31acbb-43e0-e466-c72c-aa5493ca67eb",
#     "responseId": "b829f996-c000-47b2-a91e-31da30130ac4-425db6e2"
# }
